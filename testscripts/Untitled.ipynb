# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from pandas.plotting import table
# %matplotlib inline

# %%
from fpdf import FPDF, HTMLMixin

class MyFPDF(FPDF, HTMLMixin):
    pass

# %%
data = pd.read_csv('./Formated.csv')

# %%
data.head()
# Out:
#    Unnamed: 0 GenderSelect        Country   Age  \
# 0           3         Male  United States  56.0
# 1           4         Male         Taiwan  38.0
# 2           5         Male         Brazil  46.0
# 3           6         Male  United States  35.0
# 4           7       Female          India  22.0
#
#                                     EmploymentStatus CodeWriter  \
# 0  Independent contractor, freelancer, or self-em...        Yes
# 1                                 Employed full-time        Yes
# 2                                 Employed full-time        Yes
# 3                                 Employed full-time        Yes
# 4                                 Employed full-time         No
#
#                   CurrentJobTitleSelect  MLToolNextYearSelect  \
# 0      Operations Research Practitioner            TensorFlow
# 1                    Computer Scientist            TensorFlow
# 2                        Data Scientist            TensorFlow
# 3                    Computer Scientist            TensorFlow
# 4  Software Developer/Software Engineer  Google Cloud Compute
#
#               MLMethodNextYearSelect LanguageRecommendationSelect  \
# 0                        Neural Nets                       Python
# 1                        Text Mining                       Python
# 2  Genetic & Evolutionary Algorithms                       Python
# 3                        Text Mining                            R
# 4                      Deep learning                          SQL
#
#      FormalEducation                         MajorSelect              Tenure  \
# 0    Master's degree           Mathematics or statistics  More than 10 years
# 1    Doctoral degree  Engineering (non-computer focused)  More than 10 years
# 2    Doctoral degree              Electrical Engineering       6 to 10 years
# 3    Master's degree              Electrical Engineering  More than 10 years
# 4  Bachelor's degree                    Computer Science        1 to 2 years
#
#                            FirstTrainingSelect  LearningCategorySelftTaught  \
# 0                           University courses                         30.0
# 1                           University courses                         60.0
# 2  Online courses (coursera, udemy, edx, etc.)                         45.0
# 3                           University courses                         40.0
# 4                           University courses                          0.0
#
#    LearningCategoryOnlineCourses  LearningCategoryWork  \
# 0                            0.0                  40.0
# 1                            5.0                   5.0
# 2                           25.0                  20.0
# 3                            0.0                   0.0
# 4                           40.0                   0.0
#
#    LearningCategoryUniversity  LearningCategoryKaggle  LearningCategoryOther
# 0                        30.0                     0.0                    0.0
# 1                        30.0                     0.0                    0.0
# 2                         0.0                    10.0                    0.0
# 3                        50.0                    10.0                    0.0
# 4                        50.0                    10.0                    0.0

# %%
k = data.head().to_html()
print(k)
k = data.isnull().sum()
print(k.to_frame().to_html())
k = data['extention'].value_counts()
print(k.to_frame().to_html())

# %%
test =  data.head().to_html()

# %%
print(test)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>GenderSelect</th>
#       <th>Country</th>
#       <th>Age</th>
#       <th>EmploymentStatus</th>
#       <th>CodeWriter</th>
#       <th>CurrentJobTitleSelect</th>
#       <th>MLToolNextYearSelect</th>
#       <th>MLMethodNextYearSelect</th>
#       <th>LanguageRecommendationSelect</th>
#       <th>FormalEducation</th>
#       <th>MajorSelect</th>
#       <th>Tenure</th>
#       <th>FirstTrainingSelect</th>
#       <th>LearningCategorySelftTaught</th>
#       <th>LearningCategoryOnlineCourses</th>
#       <th>LearningCategoryWork</th>
#       <th>LearningCategoryUniversity</th>
#       <th>LearningCategoryKaggle</th>
#       <th>LearningCategoryOther</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>3</td>
#       <td>Male</td>
#       <td>United States</td>
#       <td>56.0</td>
#       <td>Independent contractor, freelancer, or self-em...</td>
#       <td>Yes</td>
#       <td>Operations Research Practitioner</td>
#       <td>TensorFlow</td>
#       <td>Neural Nets</td>
#       <td>Python</td>
#       <td>Master's degree</td>
#       <td>Mathematics or statistics</td>
#       <td>More than 10 years</td>
#       <td>University courses</td>
#       <td>30.0</td>
#       <td>0.0</td>
#       <td>40.0</td>
#       <td>30.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>4</td>
#       <td>Male</td>
#       <td>Taiwan</td>
#       <td>38.0</td>
#       <td>Employed full-time</td>
#       <td>Yes</td>
#       <td>Computer Scientist</td>
#       <td>TensorFlow</td>
#       <td>Text Mining</td>
#       <td>Python</td>
#       <td>Doctoral degree</td>
#       <td>Engineering (non-computer focused)</td>
#       <td>More than 10 years</td>
#       <td>University courses</td>
#       <td>60.0</td>
#       <td>5.0</td>
#       <td>5.0</td>
#       <td>30.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5</td>
#       <td>Male</td>
#       <td>Brazil</td>
#       <td>46.0</td>
#       <td>Employed full-time</td>
#       <td>Yes</td>
#       <td>Data Scientist</td>
#       <td>TensorFlow</td>
#       <td>Genetic &amp; Evolutionary Algorithms</td>
#       <td>Python</td>
#       <td>Doctoral degree</td>
#       <td>Electrical Engineering</td>
#       <td>6 to 10 years</td>
#       <td>Online courses (coursera, udemy, edx, etc.)</td>
#       <td>45.0</td>
#       <td>25.0</td>
#       <td>20.0</td>
#       <td>0.0</td>
#       <td>10.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>6</td>
#       <td>Male</td>
#       <td>United States</td>
#       <td>35.0</td>
#       <td>Employed full-time</td>
#       <td>Yes</td>
#       <td>Computer Scientist</td>
#       <td>TensorFlow</td>
#       <td>Text Mining</td>
#       <td>R</td>
#       <td>Master's degree</td>
#       <td>Electrical Engineering</td>
#       <td>More than 10 years</td>
#       <td>University courses</td>
#       <td>40.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>50.0</td>
#       <td>10.0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>7</td>
#       <td>Female</td>
#       <td>India</td>
#       <td>22.0</td>
#       <td>Employed full-time</td>
#       <td>No</td>
#       <td>Software Developer/Software Engineer</td>
#       <td>Google Cloud Compute</td>
#       <td>Deep learning</td>
#       <td>SQL</td>
#       <td>Bachelor's degree</td>
#       <td>Computer Science</td>
#       <td>1 to 2 years</td>
#       <td>University courses</td>
#       <td>0.0</td>
#       <td>40.0</td>
#       <td>0.0</td>
#       <td>50.0</td>
#       <td>10.0</td>
#       <td>0.0</td>
#     </tr>
#   </tbody>
# </table>

# %%
from xhtml2pdf import pisa             # import python module

k = data.isnull().sum()
# Define your data
sourceHtml = "<html><body>"+k.to_frame().to_html()+"</body></html>"
outputFilename = "test.pdf"

# Utility function
def convertHtmlToPdf(sourceHtml, outputFilename):
    # open output file for writing (truncated binary)
    resultFile = open(outputFilename, "w+b")

    # convert HTML to PDF
    pisaStatus = pisa.CreatePDF(
            sourceHtml,                # the HTML to convert
            dest=resultFile)           # file handle to recieve result

    # close output file
    resultFile.close()   
convertHtmlToPdf(sourceHtml,outputFilename)

# %%
# Out:
# # Hello
